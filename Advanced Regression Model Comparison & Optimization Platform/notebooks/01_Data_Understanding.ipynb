# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


pd.set_option('display.max_columns', None)

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Test.csv dataset understanding

# %%
data = pd.read_csv('../dataset/raw/test.csv')

# %%
data.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1454         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1455         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1456         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1458         Lvl    AllPub    Inside       Mod      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
data.shape
# Out:
# (1459, 80)

# %%
print("Total Rows:", data.shape[0])
print("Total Columns:", data.shape[1])
# Out:
# Total Rows: 1459
# Total Columns: 80

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   str
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   str
#  6   Alley          107 non-null    str
#  7   LotShape       1459 non-null   str
#  8   LandContour    1459 non-null   str
#  9   Utilities      1457 non-null   str
#  10  LotConfig      1459 non-null   str
#  11  LandSlope      1459 non-null   str
#  12  Neighborhood   1459 non-null   str
#  13  Condition1     1459 non-null   str
#  14  Condition2     1459 non-null   str
#  15  BldgType       1459 non-null   str
#  16  HouseStyle     1459 non-null   str
#  17  OverallQual    1459 non-null   int64
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704
# std       1.113740    30.390071     21.130467   177.625900   455.268042
# ...

# %%
data.describe(include='object')
# Out:
# /tmp/ipykernel_496871/3382516499.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include='object')
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1455   1459   107     1459        1459      1457      1459
# unique        5      2     2        4           4         1         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1114   1453    70      934        1311      1457      1081
#
#        LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# ...

# %%
data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %%
null_values = data.isnull().sum()
null_values = null_values[null_values > 0].sort_values(ascending=False)

null_values
# Out:
# PoolQC          1456
# MiscFeature     1408
# Alley           1352
# Fence           1169
# MasVnrType       894
# FireplaceQu      730
# LotFrontage      227
# GarageQual        78
# GarageCond        78
# GarageYrBlt       78
# GarageFinish      78
# GarageType        76
# BsmtCond          45
# BsmtQual          44
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinType2      42
# MasVnrArea        15
# MSZoning           4
# Functional         2
# BsmtFullBath       2
# Utilities          2
# BsmtHalfBath       2
# Exterior1st        1
# Exterior2nd        1
# TotalBsmtSF        1
# BsmtUnfSF          1
# BsmtFinSF2         1
# BsmtFinSF1         1
# KitchenQual        1
# GarageArea         1
# GarageCars         1
# SaleType           1
# dtype: int64

# %%
null_percentage = (data.isnull().sum() / len(data)) * 100

null_percentage = null_percentage[null_percentage > 0]

null_percentage.sort_values(ascending=False)
# Out:
# PoolQC          99.794380
# MiscFeature     96.504455
# Alley           92.666210
# Fence           80.123372
# MasVnrType      61.274846
# FireplaceQu     50.034270
# LotFrontage     15.558602
# GarageQual       5.346127
# GarageCond       5.346127
# GarageYrBlt      5.346127
# GarageFinish     5.346127
# GarageType       5.209047
# BsmtCond         3.084304
# BsmtQual         3.015764
# BsmtExposure     3.015764
# BsmtFinType1     2.878684
# BsmtFinType2     2.878684
# MasVnrArea       1.028101
# MSZoning         0.274160
# Functional       0.137080
# BsmtFullBath     0.137080
# Utilities        0.137080
# BsmtHalfBath     0.137080
# Exterior1st      0.068540
# Exterior2nd      0.068540
# TotalBsmtSF      0.068540
# BsmtUnfSF        0.068540
# BsmtFinSF2       0.068540
# BsmtFinSF1       0.068540
# KitchenQual      0.068540
# GarageArea       0.068540
# GarageCars       0.068540
# SaleType         0.068540
# dtype: float64

# %%
len(null_values)
# Out:
# 33

# %%
for column in data.columns:
    print(f"Column: {column}")
# Out:
# Column: Id
# Column: MSSubClass
# Column: MSZoning
# Column: LotFrontage
# Column: LotArea
# Column: Street
# Column: Alley
# Column: LotShape
# Column: LandContour
# Column: Utilities
# Column: LotConfig
# Column: LandSlope
# Column: Neighborhood
# Column: Condition1
# Column: Condition2
# Column: BldgType
# Column: HouseStyle
# Column: OverallQual
# Column: OverallCond
# Column: YearBuilt
# Column: YearRemodAdd
# Column: RoofStyle
# Column: RoofMatl
# Column: Exterior1st
# Column: Exterior2nd
# Column: MasVnrType
# Column: MasVnrArea
# Column: ExterQual
# Column: ExterCond
# Column: Foundation
# Column: BsmtQual
# Column: BsmtCond
# Column: BsmtExposure
# Column: BsmtFinType1
# Column: BsmtFinSF1
# Column: BsmtFinType2
# Column: BsmtFinSF2
# Column: BsmtUnfSF
# Column: TotalBsmtSF
# Column: Heating
# Column: HeatingQC
# Column: CentralAir
# Column: Electrical
# Column: 1stFlrSF
# Column: 2ndFlrSF
# Column: LowQualFinSF
# Column: GrLivArea
# Column: BsmtFullBath
# ...

# %%
duplicate_rows = data.duplicated().sum()
print(f"Total Duplicate Rows: {duplicate_rows}")
# Out:
# Total Duplicate Rows: 0

# %%
for col in null_values.index:   
    print(f"Column: {col} has Null Values: {null_values[col]}")
# Out:
# Column: PoolQC has Null Values: 1456
# Column: MiscFeature has Null Values: 1408
# Column: Alley has Null Values: 1352
# Column: Fence has Null Values: 1169
# Column: MasVnrType has Null Values: 894
# Column: FireplaceQu has Null Values: 730
# Column: LotFrontage has Null Values: 227
# Column: GarageQual has Null Values: 78
# Column: GarageCond has Null Values: 78
# Column: GarageYrBlt has Null Values: 78
# Column: GarageFinish has Null Values: 78
# Column: GarageType has Null Values: 76
# Column: BsmtCond has Null Values: 45
# Column: BsmtQual has Null Values: 44
# Column: BsmtExposure has Null Values: 44
# Column: BsmtFinType1 has Null Values: 42
# Column: BsmtFinType2 has Null Values: 42
# Column: MasVnrArea has Null Values: 15
# Column: MSZoning has Null Values: 4
# Column: Functional has Null Values: 2
# Column: BsmtFullBath has Null Values: 2
# Column: Utilities has Null Values: 2
# Column: BsmtHalfBath has Null Values: 2
# Column: Exterior1st has Null Values: 1
# ...

# %%
null_values.index
# Out:
# Index(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'MasVnrType', 'FireplaceQu',
#        'LotFrontage', 'GarageQual', 'GarageCond', 'GarageYrBlt',
#        'GarageFinish', 'GarageType', 'BsmtCond', 'BsmtQual', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinType2', 'MasVnrArea', 'MSZoning', 'Functional',
#        'BsmtFullBath', 'Utilities', 'BsmtHalfBath', 'Exterior1st',
#        'Exterior2nd', 'TotalBsmtSF', 'BsmtUnfSF', 'BsmtFinSF2', 'BsmtFinSF1',
#        'KitchenQual', 'GarageArea', 'GarageCars', 'SaleType'],
#       dtype='str')

# %%
plt.figure(figsize=(14,6))

sns.heatmap(data.isnull())

plt.title("Missing Value Heatmap")

plt.show()

# %%
numerical_columns = data.select_dtypes(include=["int64","float64"])
numerical_columns
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     1461          20         80.0    11622            5            6
# 1     1462          20         81.0    14267            6            6
# 2     1463          60         74.0    13830            5            5
# 3     1464          60         78.0     9978            6            6
# 4     1465         120         43.0     5005            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1454  2915         160         21.0     1936            4            7
# 1455  2916         160         21.0     1894            4            5
# 1456  2917          20        160.0    20000            5            7
# 1457  2918          85         62.0    10441            5            5
# 1458  2919          60         74.0     9627            7            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
categorical_columns = data.select_dtypes(include="object")

categorical_columns
# Out:
# /tmp/ipykernel_496871/3995448293.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = data.select_dtypes(include="object")
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RH   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# ...

# %% [markdown]
# # Train.csv dataset understanding

# %%
Train_data = pd.read_csv("../dataset/raw/train.csv")

# %%
print("Total Train dataset shape : ", Train_data.shape)
print("Number of Rows in Train Data : " ,Train_data.shape[0])
print("Number of column in Train Data : ", Train_data.shape[1])
# Out:
# Total Train dataset shape :  (1460, 81)
# Number of Rows in Train Data :  1460
# Number of column in Train Data :  81

# %%
Train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
Train_data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
for column in Train_data.columns:
    print("column : ",column)
# Out:
# column :  Id
# column :  MSSubClass
# column :  MSZoning
# column :  LotFrontage
# column :  LotArea
# column :  Street
# column :  Alley
# column :  LotShape
# column :  LandContour
# column :  Utilities
# column :  LotConfig
# column :  LandSlope
# column :  Neighborhood
# column :  Condition1
# column :  Condition2
# column :  BldgType
# column :  HouseStyle
# column :  OverallQual
# column :  OverallCond
# column :  YearBuilt
# column :  YearRemodAdd
# column :  RoofStyle
# column :  RoofMatl
# column :  Exterior1st
# column :  Exterior2nd
# column :  MasVnrType
# column :  MasVnrArea
# column :  ExterQual
# column :  ExterCond
# column :  Foundation
# column :  BsmtQual
# column :  BsmtCond
# column :  BsmtExposure
# column :  BsmtFinType1
# column :  BsmtFinSF1
# column :  BsmtFinType2
# column :  BsmtFinSF2
# column :  BsmtUnfSF
# column :  TotalBsmtSF
# column :  Heating
# column :  HeatingQC
# column :  CentralAir
# column :  Electrical
# column :  1stFlrSF
# ...

# %%
Train_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   str
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   str
#  6   Alley          91 non-null     str
#  7   LotShape       1460 non-null   str
#  8   LandContour    1460 non-null   str
#  9   Utilities      1460 non-null   str
#  10  LotConfig      1460 non-null   str
#  11  LandSlope      1460 non-null   str
#  12  Neighborhood   1460 non-null   str
#  13  Condition1     1460 non-null   str
#  14  Condition2     1460 non-null   str
#  15  BldgType       1460 non-null   str
#  16  HouseStyle     1460 non-null   str
#  17  OverallQual    1460 non-null   int64
# ...

# %%
Train_data.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %%
Train_data.describe(include="object").T
# Out:
# /tmp/ipykernel_496871/462979644.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   Train_data.describe(include="object").T
#               count unique      top  freq
# MSZoning       1460      5       RL  1151
# Street         1460      2     Pave  1454
# Alley            91      2     Grvl    50
# LotShape       1460      4      Reg   925
# LandContour    1460      4      Lvl  1311
# Utilities      1460      2   AllPub  1459
# LotConfig      1460      5   Inside  1052
# LandSlope      1460      3      Gtl  1382
# Neighborhood   1460     25    NAmes   225
# ...

# %%
numerical_columns_Train_data = Train_data.select_dtypes(include=np.number)
numerical_columns_Train_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='str')

# %%
len(numerical_columns_Train_data.columns)
# Out:
# 38

# %%
categorical_columns_Train_data = Train_data.select_dtypes(include="object")
categorical_columns_Train_data.columns
# Out:
# /tmp/ipykernel_496871/2227140623.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns_Train_data = Train_data.select_dtypes(include="object")
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
# ...

# %%
len(categorical_columns_Train_data.columns)
# Out:
# 43

# %%
train_data_null_values = Train_data.isnull().sum()
train_data_null_values
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
train_data_null_values = Train_data.isnull().sum()
train_data_null_values = train_data_null_values[train_data_null_values > 0].sort_values(ascending=False)
print(train_data_null_values)
print(len(train_data_null_values))
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# dtype: int64
# 19

# %%
plt.figure(figsize=(14,6))

sns.heatmap(Train_data.isnull(), cbar=False)

plt.title("Missing Value Heatmap")

plt.show()

# %%
duplicate_rows_train_data = Train_data.duplicated().sum()
print("Total duplicated value in Trained dataset : ",duplicate_rows_train_data)
# Out:
# Total duplicated value in Trained dataset :  0

# %%
target_varDis_train_data = Train_data["SalePrice"]
target_varDis_train_data
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
print("Sum of the Target Variable Distribution : ", target_varDis_train_data.sum())
print("Min of the Target Variable Distribution : ",target_varDis_train_data.min())
print("Max of the Target Variable Distribution : ",target_varDis_train_data.max())
print("Mean of the Target Variable Distribution : ",target_varDis_train_data.mean())
print("Median of the Target Variable Distribution : ",target_varDis_train_data.median())
# Out:
# Sum of the Target Variable Distribution :  264144946
# Min of the Target Variable Distribution :  34900
# Max of the Target Variable Distribution :  755000
# Mean of the Target Variable Distribution :  180921.19589041095
# Median of the Target Variable Distribution :  163000.0

# %%
plt.Figure(figsize=(14,6))

plt.hist(target_varDis_train_data)

plt.title("Sales Price Value Distribution")

plt.show()

# %%
target_varDis_train_data[target_varDis_train_data > 700000].count()
# Out:
# np.int64(2)

# %%
target_varDis_train_data[target_varDis_train_data < 100000].count()
# Out:
# np.int64(114)

# %% [markdown]
# # Find the Correlation of numerical values

# %%
corr_Train_data = numerical_columns_Train_data.corr()
corr_Train_data
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
len(corr_Train_data)
# Out:
# 38

# %%
plt.figure(figsize=(20,14))

sns.heatmap(
    numerical_columns_Train_data.corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    cbar = False
)

plt.title("Correlation Heatmap")

plt.show()

plt.savefig("../figures/phase_01/Correlation_heatMap.png",
            dpi=300,
            bbox_inches="tight")

# %%
for i in numerical_columns_Train_data.corr():
    print(i)
# Out:
# Id
# MSSubClass
# LotFrontage
# LotArea
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# MasVnrArea
# BsmtFinSF1
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# GrLivArea
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# TotRmsAbvGrd
# Fireplaces
# GarageYrBlt
# GarageCars
# GarageArea
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# MiscVal
# MoSold
# YrSold
# SalePrice

# %%
corr_matrix = numerical_columns_Train_data.corr()

corr_matrix.items
# Out:
# <bound method DataFrame.items of                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
for col_name, row_values in corr_matrix.items():
    for row_name, corr_val in row_values.items():
        
        if col_name != row_name:
            print(f"Correlation between {col_name} and {row_name}: {corr_val:.2f}")
# Out:
# Correlation between Id and MSSubClass: 0.01
# Correlation between Id and LotFrontage: -0.01
# Correlation between Id and LotArea: -0.03
# Correlation between Id and OverallQual: -0.03
# Correlation between Id and OverallCond: 0.01
# Correlation between Id and YearBuilt: -0.01
# Correlation between Id and YearRemodAdd: -0.02
# Correlation between Id and MasVnrArea: -0.05
# Correlation between Id and BsmtFinSF1: -0.01
# Correlation between Id and BsmtFinSF2: -0.01
# Correlation between Id and BsmtUnfSF: -0.01
# Correlation between Id and TotalBsmtSF: -0.02
# Correlation between Id and 1stFlrSF: 0.01
# Correlation between Id and 2ndFlrSF: 0.01
# Correlation between Id and LowQualFinSF: -0.04
# Correlation between Id and GrLivArea: 0.01
# Correlation between Id and BsmtFullBath: 0.00
# Correlation between Id and BsmtHalfBath: -0.02
# Correlation between Id and FullBath: 0.01
# Correlation between Id and HalfBath: 0.01
# Correlation between Id and BedroomAbvGr: 0.04
# ...

# %%
print(type(corr_matrix.items))
# Out:
# <class 'method'>

# %%
target_var_corr = numerical_columns_Train_data.corr()["SalePrice"]

# %%
target_var_corr
# Out:
# Id              -0.021917
# MSSubClass      -0.084284
# LotFrontage      0.351799
# LotArea          0.263843
# OverallQual      0.790982
# OverallCond     -0.077856
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.477493
# BsmtFinSF1       0.386420
# BsmtFinSF2      -0.011378
# BsmtUnfSF        0.214479
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# 2ndFlrSF         0.319334
# LowQualFinSF    -0.025606
# GrLivArea        0.708624
# BsmtFullBath     0.227122
# BsmtHalfBath    -0.016844
# FullBath         0.560664
# HalfBath         0.284108
# BedroomAbvGr     0.168213
# KitchenAbvGr    -0.135907
# TotRmsAbvGrd     0.533723
# Fireplaces       0.466929
# GarageYrBlt      0.486362
# GarageCars       0.640409
# GarageArea       0.623431
# WoodDeckSF       0.324413
# OpenPorchSF      0.315856
# EnclosedPorch   -0.128578
# 3SsnPorch        0.044584
# ScreenPorch      0.111447
# PoolArea         0.092404
# MiscVal         -0.021190
# ...

# %%
plt.Figure(figsize=(12,10))

sns.histplot(target_var_corr)

plt.title("Relevant features with Sales Price")

plt.show()

# %% [markdown]
# # I set My Own Threshold Value of 0.50

# %%
threshold = 0.50

# %%
target_var_corr.__class__
# Out:
# pandas.Series

# %%
relevant_features = {}

for row, cols in target_var_corr.items():
    if cols >= threshold and row != "SalePrice":
        relevant_features[row] = cols

# %%
relevant_features
# Out:
# {'OverallQual': 0.7909816005838053,
#  'YearBuilt': 0.5228973328794967,
#  'YearRemodAdd': 0.5071009671113866,
#  'TotalBsmtSF': 0.6135805515591943,
#  '1stFlrSF': 0.6058521846919153,
#  'GrLivArea': 0.7086244776126515,
#  'FullBath': 0.5606637627484453,
#  'TotRmsAbvGrd': 0.5337231555820284,
#  'GarageCars': 0.6404091972583519,
#  'GarageArea': 0.6234314389183622}

# %%
plt.Figure(figsize=(12,10))

sns.histplot(relevant_features, kde = True)

plt.title("Relevant features with Sales Price")

plt.show()

# %%
plt.savefig("../figures/phase_01/Relevant_features_for_saleprice.png",
            dpi=300,
            bbox_inches="tight")

# %% [markdown]
# # Data Understanding Completed
